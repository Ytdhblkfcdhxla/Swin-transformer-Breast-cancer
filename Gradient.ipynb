# %%
import os
import numpy as np
import nibabel as nib
import scipy.ndimage as ndi
import matplotlib.pyplot as plt
from skimage import exposure

def apply_window_level(image, window_width, window_level):
    """
    根据给定的窗宽和窗位调整图像的灰度值。
    
    参数：
        image (numpy.ndarray): 原始图像数据。
        window_width (int): 窗宽。
        window_level (int): 窗位。
        
    返回：
        numpy.ndarray: 调整后的图像数据。
    """
    min_window = window_level - window_width // 2
    max_window = window_level + window_width // 2
    
    # 应用窗宽和窗位
    adjusted_image = np.clip(image, min_window, max_window)
    adjusted_image = ((adjusted_image - min_window) / (max_window - min_window)) * 255.0
    return adjusted_image.astype(np.uint8)

def calculate_gradient_based_window(image):
    """
    基于图像梯度计算窗宽和窗位。
    
    参数：
        image (numpy.ndarray): 原始图像数据。
        
    返回：
        tuple: 窗宽和窗位。
    """
    # 使用Sobel算子计算图像的梯度（考虑更多方向）
    sobel_x = ndi.sobel(image.astype(np.float32), axis=0)
    sobel_y = ndi.sobel(image.astype(np.float32), axis=1)
    sobel_z = ndi.sobel(image.astype(np.float32), axis=2)
    
    gradient = np.sqrt(sobel_x**2 + sobel_y**2 + sobel_z**2)
    
    # 计算梯度的均值和标准差
    mean_gradient = np.mean(gradient)
    std_gradient = np.std(gradient)
    
    # 根据梯度统计信息确定窗位和窗宽
    window_level = mean_gradient
    window_width = 4 * std_gradient  # 可以根据具体需求调整此系数
    
    return window_width, window_level

def enhance_contrast(image):
    """
    使用自适应直方图均衡化增强图像对比度。
    
    参数：
        image (numpy.ndarray): 原始图像数据。
        
    返回：
        numpy.ndarray: 对比度增强后的图像数据。
    """
    # 归一化图像到0到1之间
    image = image.astype(np.float32)
    image = (image - np.min(image)) / (np.max(image) - np.min(image))
    
    # 自适应直方图均衡化
    enhanced_image = exposure.equalize_adapthist(image)
    return (enhanced_image * 255).astype(np.uint8)

def process_image_file(input_path, output_path):
    """
    处理单个 .nii.gz 文件并保存调整后的图像。
    
    参数：
        input_path (str): 输入 .nii.gz 文件的路径。
        output_path (str): 保存调整后的 .nii.gz 文件的路径。
    """
    # 加载NIfTI文件
    img = nib.load(input_path)
    image_data = img.get_fdata()

    # 基于梯度计算窗宽和窗位
    window_width, window_level = calculate_gradient_based_window(image_data)

    # 根据计算出的窗宽和窗位调整图像
    adjusted_image = apply_window_level(image_data, window_width, window_level)
    
    # 增强图像对比度
    enhanced_image = enhance_contrast(adjusted_image)

    # 将调整后的图像保存为新的NIfTI文件
    adjusted_img = nib.Nifti1Image(enhanced_image, img.affine, img.header)
    nib.save(adjusted_img, output_path)

def batch_process_images(input_folder, output_folder):
    """
    批量处理输入文件夹中的所有 .nii.gz 文件，并保存到输出文件夹。
    
    参数：
        input_folder (str): 包含 .nii.gz 文件的输入文件夹路径。
        output_folder (str): 保存调整后 .nii.gz 文件的输出文件夹路径。
    """
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith('.nii.gz'):
            input_path = os.path.join(input_folder, filename)
            output_path = os.path.join(output_folder, filename)
            process_image_file(input_path, output_path)
            print(f'已处理 {filename}')

def process_image_file(input_path, output_path):
    try:
        img = nib.load(input_path)
        image_data = img.get_fdata()
        window_width, window_level = calculate_gradient_based_window(image_data)
        adjusted_image = apply_window_level(image_data, window_width, window_level)
        enhanced_image = enhance_contrast(adjusted_image)
        adjusted_img = nib.Nifti1Image(enhanced_image, img.affine, img.header)
        nib.save(adjusted_img, output_path)
        print(f'已处理 {input_path}')
    except Exception as e:
        print(f'处理 {input_path} 时出错: {e}')

            
# 设置输入和输出文件夹路径
input_folder = r'G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2'  # 替换为实际输入文件夹路径
output_folder = r'G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2_gradient'  # 替换为实际输出文件夹路径

# 批量处理图像
batch_process_images(input_folder, output_folder)
# Out:
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX001_T2.nii.gz
# 已处理 JX001_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX002_T2.nii.gz
# 已处理 JX002_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX003_T2.nii.gz
# 已处理 JX003_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX004_T2.nii.gz
# 已处理 JX004_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX005_T2.nii.gz
# 已处理 JX005_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX006_T2.nii.gz
# 已处理 JX006_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX007_T2.nii.gz
# 已处理 JX007_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX008_T2.nii.gz
# 已处理 JX008_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX009_T2.nii.gz
# 已处理 JX009_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX010_T2.nii.gz
# 已处理 JX010_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX011_T2.nii.gz
# 已处理 JX011_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX012_T2.nii.gz
# 已处理 JX012_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX013_T2.nii.gz
# 已处理 JX013_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX014_T2.nii.gz
# 已处理 JX014_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX015_T2.nii.gz
# 已处理 JX015_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX016_T2.nii.gz
# 已处理 JX016_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX017_T2.nii.gz
# 已处理 JX017_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX018_T2.nii.gz
# 已处理 JX018_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX019_T2.nii.gz
# 已处理 JX019_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX020_T2.nii.gz
# 已处理 JX020_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX021_T2.nii.gz
# 已处理 JX021_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX022_T2.nii.gz
# 已处理 JX022_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX023_T2.nii.gz
# 已处理 JX023_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX024_T2.nii.gz
# 已处理 JX024_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX025_T2.nii.gz
# 已处理 JX025_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX026_T2.nii.gz
# 已处理 JX026_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX027_T2.nii.gz
# 已处理 JX027_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX028_T2.nii.gz
# 已处理 JX028_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX029_T2.nii.gz
# 已处理 JX029_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX030_T2.nii.gz
# 已处理 JX030_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX031_T2.nii.gz
# 已处理 JX031_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX032_T2.nii.gz
# 已处理 JX032_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX033_T2.nii.gz
# 已处理 JX033_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX034_T2.nii.gz
# 已处理 JX034_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX035_T2.nii.gz
# 已处理 JX035_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX036_T2.nii.gz
# 已处理 JX036_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX037_T2.nii.gz
# 已处理 JX037_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX038_T2.nii.gz
# 已处理 JX038_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX039_T2.nii.gz
# 已处理 JX039_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX040_T2.nii.gz
# 已处理 JX040_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX041_T2.nii.gz
# 已处理 JX041_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX042_T2.nii.gz
# 已处理 JX042_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX043_T2.nii.gz
# 已处理 JX043_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX044_T2.nii.gz
# 已处理 JX044_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX045_T2.nii.gz
# 已处理 JX045_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX046_T2.nii.gz
# 已处理 JX046_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX047_T2.nii.gz
# 已处理 JX047_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX048_T2.nii.gz
# 已处理 JX048_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX049_T2.nii.gz
# 已处理 JX049_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX050_T2.nii.gz
# 已处理 JX050_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX051_T2.nii.gz
# 已处理 JX051_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX052_T2.nii.gz
# 已处理 JX052_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX053_T2.nii.gz
# 已处理 JX053_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX054_T2.nii.gz
# 已处理 JX054_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX055_T2.nii.gz
# 已处理 JX055_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX056_T2.nii.gz
# 已处理 JX056_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX057_T2.nii.gz
# 已处理 JX057_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX058_T2.nii.gz
# 已处理 JX058_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX059_T2.nii.gz
# 已处理 JX059_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX060_T2.nii.gz
# 已处理 JX060_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX061_T2.nii.gz
# 已处理 JX061_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX062_T2.nii.gz
# 已处理 JX062_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX063_T2.nii.gz
# 已处理 JX063_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX064_T2.nii.gz
# 已处理 JX064_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX065_T2.nii.gz
# 已处理 JX065_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX066_T2.nii.gz
# 已处理 JX066_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX067_T2.nii.gz
# 已处理 JX067_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX068_T2.nii.gz
# 已处理 JX068_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX069_T2.nii.gz
# 已处理 JX069_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX070_T2.nii.gz
# 已处理 JX070_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX071_T2.nii.gz
# 已处理 JX071_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX072_T2.nii.gz
# 已处理 JX072_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX073_T2.nii.gz
# 已处理 JX073_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX074_T2.nii.gz
# 已处理 JX074_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX075_T2.nii.gz
# 已处理 JX075_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX076_T2.nii.gz
# 已处理 JX076_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX077_T2.nii.gz
# 已处理 JX077_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX078_T2.nii.gz
# 已处理 JX078_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX079_T2.nii.gz
# 已处理 JX079_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX080_T2.nii.gz
# 已处理 JX080_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX081_T2.nii.gz
# 已处理 JX081_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX082_T2.nii.gz
# 已处理 JX082_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX083_T2.nii.gz
# 已处理 JX083_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX084_T2.nii.gz
# 已处理 JX084_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX085_T2.nii.gz
# 已处理 JX085_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX086_T2.nii.gz
# 已处理 JX086_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX087_T2.nii.gz
# 已处理 JX087_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX088_T2.nii.gz
# 已处理 JX088_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX089_T2.nii.gz
# 已处理 JX089_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX090_T2.nii.gz
# 已处理 JX090_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX091_T2.nii.gz
# 已处理 JX091_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX092_T2.nii.gz
# 已处理 JX092_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX093_T2.nii.gz
# 已处理 JX093_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX094_T2.nii.gz
# 已处理 JX094_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX095_T2.nii.gz
# 已处理 JX095_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX096_T2.nii.gz
# 已处理 JX096_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX097_T2.nii.gz
# 已处理 JX097_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX098_T2.nii.gz
# 已处理 JX098_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX099_T2.nii.gz
# 已处理 JX099_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX100_T2.nii.gz
# 已处理 JX100_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX101_T2.nii.gz
# 已处理 JX101_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX102_T2.nii.gz
# 已处理 JX102_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX103_T2.nii.gz
# 已处理 JX103_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX104_T2.nii.gz
# 已处理 JX104_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX105_T2.nii.gz
# 已处理 JX105_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX106_T2.nii.gz
# 已处理 JX106_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX107_T2.nii.gz
# 已处理 JX107_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX108_T2.nii.gz
# 已处理 JX108_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX109_T2.nii.gz
# 已处理 JX109_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX110_T2.nii.gz
# 已处理 JX110_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX111_T2.nii.gz
# 已处理 JX111_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX112_T2.nii.gz
# 已处理 JX112_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX113_T2.nii.gz
# 已处理 JX113_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX114_T2.nii.gz
# 已处理 JX114_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX115_T2.nii.gz
# 已处理 JX115_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX116_T2.nii.gz
# 已处理 JX116_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX117_T2.nii.gz
# 已处理 JX117_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX118_T2.nii.gz
# 已处理 JX118_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX119_T2.nii.gz
# 已处理 JX119_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX120_T2.nii.gz
# 已处理 JX120_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX121_T2.nii.gz
# 已处理 JX121_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX122_T2.nii.gz
# 已处理 JX122_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX123_T2.nii.gz
# 已处理 JX123_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX124_T2.nii.gz
# 已处理 JX124_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX125_T2.nii.gz
# 已处理 JX125_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX126_T2.nii.gz
# 已处理 JX126_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX127_T2.nii.gz
# 已处理 JX127_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX128_T2.nii.gz
# 已处理 JX128_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX129_T2.nii.gz
# 已处理 JX129_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX130_T2.nii.gz
# 已处理 JX130_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX131_T2.nii.gz
# 已处理 JX131_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX132_T2.nii.gz
# 已处理 JX132_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX133_T2.nii.gz
# 已处理 JX133_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX134_T2.nii.gz
# 已处理 JX134_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX135_T2.nii.gz
# 已处理 JX135_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX136_T2.nii.gz
# 已处理 JX136_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX137_T2.nii.gz
# 已处理 JX137_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX138_T2.nii.gz
# 已处理 JX138_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX139_T2.nii.gz
# 已处理 JX139_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX140_T2.nii.gz
# 已处理 JX140_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX141_T2.nii.gz
# 已处理 JX141_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX142_T2.nii.gz
# 已处理 JX142_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX143_T2.nii.gz
# 已处理 JX143_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX144_T2.nii.gz
# 已处理 JX144_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX145_T2.nii.gz
# 已处理 JX145_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX146_T2.nii.gz
# 已处理 JX146_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX147_T2.nii.gz
# 已处理 JX147_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX148_T2.nii.gz
# 已处理 JX148_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX149_T2.nii.gz
# 已处理 JX149_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX150_T2.nii.gz
# 已处理 JX150_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX151_T2.nii.gz
# 已处理 JX151_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX152_T2.nii.gz
# 已处理 JX152_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX153_T2.nii.gz
# 已处理 JX153_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX154_T2.nii.gz
# 已处理 JX154_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX155_T2.nii.gz
# 已处理 JX155_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX156_T2.nii.gz
# 已处理 JX156_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX157_T2.nii.gz
# 已处理 JX157_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX158_T2.nii.gz
# 已处理 JX158_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX159_T2.nii.gz
# 已处理 JX159_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX160_T2.nii.gz
# 已处理 JX160_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX161_T2.nii.gz
# 已处理 JX161_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX162_T2.nii.gz
# 已处理 JX162_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX163_T2.nii.gz
# 已处理 JX163_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX164_T2.nii.gz
# 已处理 JX164_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX165_T2.nii.gz
# 已处理 JX165_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX166_T2.nii.gz
# 已处理 JX166_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX167_T2.nii.gz
# 已处理 JX167_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX168_T2.nii.gz
# 已处理 JX168_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX169_T2.nii.gz
# 已处理 JX169_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX170_T2.nii.gz
# 已处理 JX170_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX171_T2.nii.gz
# 已处理 JX171_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX172_T2.nii.gz
# 已处理 JX172_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX173_T2.nii.gz
# 已处理 JX173_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX174_T2.nii.gz
# 已处理 JX174_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX175_T2.nii.gz
# 已处理 JX175_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX176_T2.nii.gz
# 已处理 JX176_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX177_T2.nii.gz
# 已处理 JX177_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX178_T2.nii.gz
# 已处理 JX178_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX179_T2.nii.gz
# 已处理 JX179_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX180_T2.nii.gz
# 已处理 JX180_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX181_T2.nii.gz
# 已处理 JX181_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX182_T2.nii.gz
# 已处理 JX182_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX183_T2.nii.gz
# 已处理 JX183_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX184_T2.nii.gz
# 已处理 JX184_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX185_T2.nii.gz
# 已处理 JX185_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX186_T2.nii.gz
# 已处理 JX186_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX187_T2.nii.gz
# 已处理 JX187_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX188_T2.nii.gz
# 已处理 JX188_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX189_T2.nii.gz
# 已处理 JX189_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX190_T2.nii.gz
# 已处理 JX190_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX191_T2.nii.gz
# 已处理 JX191_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX192_T2.nii.gz
# 已处理 JX192_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX193_T2.nii.gz
# 已处理 JX193_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX194_T2.nii.gz
# 已处理 JX194_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX195_T2.nii.gz
# 已处理 JX195_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX196_T2.nii.gz
# 已处理 JX196_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX197_T2.nii.gz
# 已处理 JX197_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX198_T2.nii.gz
# 已处理 JX198_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX199_T2.nii.gz
# 已处理 JX199_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX200_T2.nii.gz
# 已处理 JX200_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX201_T2.nii.gz
# 已处理 JX201_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX202_T2.nii.gz
# 已处理 JX202_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX203_T2.nii.gz
# 已处理 JX203_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX204_T2.nii.gz
# 已处理 JX204_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX205_T2.nii.gz
# 已处理 JX205_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX206_T2.nii.gz
# 已处理 JX206_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX207_T2.nii.gz
# 已处理 JX207_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX208_T2.nii.gz
# 已处理 JX208_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX209_T2.nii.gz
# 已处理 JX209_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX210_T2.nii.gz
# 已处理 JX210_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX211_T2.nii.gz
# 已处理 JX211_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX212_T2.nii.gz
# 已处理 JX212_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX213_T2.nii.gz
# 已处理 JX213_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX214_T2.nii.gz
# 已处理 JX214_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX215_T2.nii.gz
# 已处理 JX215_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX216_T2.nii.gz
# 已处理 JX216_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX217_T2.nii.gz
# 已处理 JX217_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX218_T2.nii.gz
# 已处理 JX218_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX219_T2.nii.gz
# 已处理 JX219_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX220_T2.nii.gz
# 已处理 JX220_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX221_T2.nii.gz
# 已处理 JX221_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX222_T2.nii.gz
# 已处理 JX222_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX223_T2.nii.gz
# 已处理 JX223_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX224_T2.nii.gz
# 已处理 JX224_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX225_T2.nii.gz
# 已处理 JX225_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX226_T2.nii.gz
# 已处理 JX226_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX227_T2.nii.gz
# 已处理 JX227_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX228_T2.nii.gz
# 已处理 JX228_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX229_T2.nii.gz
# 已处理 JX229_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX230_T2.nii.gz
# 已处理 JX230_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX231_T2.nii.gz
# 已处理 JX231_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX232_T2.nii.gz
# 已处理 JX232_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX233_T2.nii.gz
# 已处理 JX233_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX234_T2.nii.gz
# 已处理 JX234_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX235_T2.nii.gz
# 已处理 JX235_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX236_T2.nii.gz
# 已处理 JX236_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX237_T2.nii.gz
# 已处理 JX237_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX238_T2.nii.gz
# 已处理 JX238_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX239_T2.nii.gz
# 已处理 JX239_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX240_T2.nii.gz
# 已处理 JX240_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX241_T2.nii.gz
# 已处理 JX241_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX242_T2.nii.gz
# 已处理 JX242_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX243_T2.nii.gz
# 已处理 JX243_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX244_T2.nii.gz
# 已处理 JX244_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX245_T2.nii.gz
# 已处理 JX245_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX246_T2.nii.gz
# 已处理 JX246_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX247_T2.nii.gz
# 已处理 JX247_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX248_T2.nii.gz
# 已处理 JX248_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX249_T2.nii.gz
# 已处理 JX249_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX250_T2.nii.gz
# 已处理 JX250_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX251_T2.nii.gz
# 已处理 JX251_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX252_T2.nii.gz
# 已处理 JX252_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX253_T2.nii.gz
# 已处理 JX253_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX254_T2.nii.gz
# 已处理 JX254_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX255_T2.nii.gz
# 已处理 JX255_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX256_T2.nii.gz
# 已处理 JX256_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX257_T2.nii.gz
# 已处理 JX257_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX258_T2.nii.gz
# 已处理 JX258_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX259_T2.nii.gz
# 已处理 JX259_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX260_T2.nii.gz
# 已处理 JX260_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX261_T2.nii.gz
# 已处理 JX261_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX262_T2.nii.gz
# 已处理 JX262_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX263_T2.nii.gz
# 已处理 JX263_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX264_T2.nii.gz
# 已处理 JX264_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX265_T2.nii.gz
# 已处理 JX265_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX266_T2.nii.gz
# 已处理 JX266_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX267_T2.nii.gz
# 已处理 JX267_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX268_T2.nii.gz
# 已处理 JX268_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX269_T2.nii.gz
# 已处理 JX269_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX270_T2.nii.gz
# 已处理 JX270_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX271_T2.nii.gz
# 已处理 JX271_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX272_T2.nii.gz
# 已处理 JX272_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX273_T2.nii.gz
# 已处理 JX273_T2.nii.gz
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_6068\1969462394.py:67: RuntimeWarning: invalid value encountered in divide
#   image = (image - np.min(image)) / (np.max(image) - np.min(image))
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX274_T2.nii.gz
# 已处理 JX274_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX275_T2.nii.gz
# 已处理 JX275_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX276_T2.nii.gz
# 已处理 JX276_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX277_T2.nii.gz
# 已处理 JX277_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX278_T2.nii.gz
# 已处理 JX278_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX279_T2.nii.gz
# 已处理 JX279_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX280_T2.nii.gz
# 已处理 JX280_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX281_T2.nii.gz
# 已处理 JX281_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX282_T2.nii.gz
# 已处理 JX282_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX283_T2.nii.gz
# 已处理 JX283_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX284_T2.nii.gz
# 已处理 JX284_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX285_T2.nii.gz
# 已处理 JX285_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX286_T2.nii.gz
# 已处理 JX286_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX287_T2.nii.gz
# 已处理 JX287_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX288_T2.nii.gz
# 已处理 JX288_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX289_T2.nii.gz
# 已处理 JX289_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX290_T2.nii.gz
# 已处理 JX290_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX291_T2.nii.gz
# 已处理 JX291_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX292_T2.nii.gz
# 已处理 JX292_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX293_T2.nii.gz
# 已处理 JX293_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX294_T2.nii.gz
# 已处理 JX294_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX295_T2.nii.gz
# 已处理 JX295_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX296_T2.nii.gz
# 已处理 JX296_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX297_T2.nii.gz
# 已处理 JX297_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX298_T2.nii.gz
# 已处理 JX298_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX299_T2.nii.gz
# 已处理 JX299_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX300_T2.nii.gz
# 已处理 JX300_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX301_T2.nii.gz
# 已处理 JX301_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX302_T2.nii.gz
# 已处理 JX302_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX303_T2.nii.gz
# 已处理 JX303_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX304_T2.nii.gz
# 已处理 JX304_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX305_T2.nii.gz
# 已处理 JX305_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX306_T2.nii.gz
# 已处理 JX306_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX307_T2.nii.gz
# 已处理 JX307_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX308_T2.nii.gz
# 已处理 JX308_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX309_T2.nii.gz
# 已处理 JX309_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX310_T2.nii.gz
# 已处理 JX310_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX311_T2.nii.gz
# 已处理 JX311_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX312_T2.nii.gz
# 已处理 JX312_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX313_T2.nii.gz
# 已处理 JX313_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX314_T2.nii.gz
# 已处理 JX314_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX315_T2.nii.gz
# 已处理 JX315_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX316_T2.nii.gz
# 已处理 JX316_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX317_T2.nii.gz
# 已处理 JX317_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX318_T2.nii.gz
# 已处理 JX318_T2.nii.gz
# 已处理 G:\Rectal\images\JX_hospital\JX_Hospital_nii\T2\JX319_T2.nii.gz
# 已处理 JX319_T2.nii.gz
